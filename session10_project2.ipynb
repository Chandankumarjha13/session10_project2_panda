# %% [markdown]
# This assignment gives you a practical introduction to data handling and manipulation using
# the pandas library. This project walks you through the following data handling tasks:
# 1. how to load data from a file
# 2. how to summarize the contents of a file
# 3. how to change row/column names
# 4. how to sort data by column
# 5. how to get data from a table and store it in a variable.
# You will also learn how to relate data in different tables using table joins and look for
# null values and remove them.

# %%
'''
Importing pandas, numpy and matplotlib.pyplot and alias it as pd, np and plt

# %matplotlib inline will make plot outputs appear and be stored within the notebook.

Used read_csv function of panda module to read csv files
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/data-text.csv')
df.head(2)
df1 = pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# Output:
#
#
# STATION	STATION_NAME	DATE	PRCP	SNWD	SNOW	TMAX	TMIN	WDFG	PGTM	...	WT09	WT07	WT01	WT06	WT05	WT04	WT16	WT08	WT18	WT03
# 0	GHCND:GME00111445	BERLIN TEMPELHOF GM	19310101	46	-9999	-9999	-9999	-11	-9999	-9999	...	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999
# 1	GHCND:GME00111445	BERLIN TEMPELHOF GM	19310102	107	-9999	-9999	50	11	-9999	-9999	...	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999	-9999
# 2 rows × 21 columns

# %% [markdown]
# 1. Get the Metadata from the above files.

# %%
# Pandas dataframe.info() function is used to get a concise summary of the dataframe. 
# It helps in doing exploratory analysis of the data.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %% [markdown]
# 2. Get the row names from the above files.

# %%
#  Index.get_values() function  return the Index value as a numpy array.
index_labels = df.index.get_values()

index_labels
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
index_labels2 = df1.index.get_values()
index_labels2
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %% [markdown]
# 3. Change the column name from any of the above file.

# %%
# Pandas rename() method is used to rename any index, column or row
df=df.rename(columns = {'Indicator':'Indicator_id'})
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# 4. Change the column name from any of the above file and store the changes made permanently.
# 5. Change the names of multiple columns.

# %%
# In  pandas inplace=True is getting used to change the object inplace. So that changes will become permanent in
# dataframe
#rename function of panda can change multiple column name
df.rename(columns={'PUBLISH STATES':'Publication Status', 'WHO region':'WHO Region'}, inplace=True)

# %%
df.head()
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# 6. Arrange values of a particular column in ascending order.

# %%
# sort_values function will sort data in ascenting order by default.for descending we need to pass parameter.
# df.sort_values(['Year'], ascending=[True])
sorted_df = df.sort_values(by='Year')
sorted_df
# Out:
#                                          Indicator_id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# 7. Arrange multiple column values in ascending

# %%
# Arrange multiple column values in ascending order
# df.head(2)
# sort_values will take multiple column name as list to arrange mutiple in sorted order

df.sort_values(['Indicator_id', 'Country', 'Year', 'WHO Region'], ascending=[True, True, True, True])
# Out:
#                                          Indicator_id Publication Status  \
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 3689  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 2598  Healthy life expectancy (HALE) at birth (years)          Published
# 3690  Healthy life expectancy (HALE) at birth (years)          Published
# 3691  Healthy life expectancy (HALE) at birth (years)          Published
# 2599  Healthy life expectancy (HALE) at birth (years)          Published
# 3692  Healthy life expectancy (HALE) at birth (years)          Published
# 4064  Healthy life expectancy (HALE) at birth (years)          Published
# ...

# %% [markdown]
# # 8. Make countryas the first column of the dataframe.

# %%
# my_dataframe.columns.values.tolist()
# .columns returns an Index, .columns.values returns an array and this has a helper function to return a list.

# ['Country'] + will add Country as first column

# unique will delete duplicate 2nd column from datafram

df[pd.unique(['Country'] + df.columns.values.tolist()).tolist()].head()
# Out:
#                 Country                       Indicator_id Publication Status  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %% [markdown]
# 9. Get the column array using a variable

# %%
# DataFrame.values
# # Return a Numpy representation of the DataFrame.

# # Only the values in the DataFrame will be returned, the axes labels will be removed.
df['WHO Region'].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %% [markdown]
# 10. Get the subset rows 11, 24, 37

# %%
# This will start from 11 till 40 with interval of 13
# start:end:interval
df[11:40:13]
# Out:
#                          Indicator_id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
#this will delete row need to exclude and remaining all row will get selected
df.drop([5,12,23,56], axis=0).head(5)
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# Load datasets from CSV
# users
# = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/ users.csv')
# sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/ sessions.csv')
# products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/ products.csv')
# transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/ transactions.csv')
# users.head()
# sessions.head()
# transactions.head()

# %%
#using read_csv function of panda to read different csv file. head function will get used to print first 5 data
users=pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/users.csv')
sessions =pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/sessions.csv') 
products =pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/products.csv') 
transactions =pd.read_csv('/home/chandan/Desktop/Learning_Material/MG/Course/BT/project2/transactions.csv') 
users.head()
sessions.head()
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# 12. Join users to transactions, keeping all rows from transactions and only matching
# rows from users (left join)

# %%
# printing 1st few value of data fram to understand the data of dataframe
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
# convert date column to date type
users['Registered'] = pd.to_datetime(users.Registered)
sessions['SessionDate'] = pd.to_datetime(sessions.SessionDate)
users['Cancelled'] = pd.to_datetime(users.Cancelled)
transactions['TransactionDate'] = pd.to_datetime(transactions.TransactionDate)

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
# pd.merge(transactions, users, how='left',on=['UserID'])
#merge function of panda takes multiple argumnet like name of data frame to join ,optional argument how takes type of join we 
# we wanr to do (default is inner join), optional argument on takes name of column to join
pd.merge(transactions, users, how='left',on='UserID')
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21      7          2         1       NaN
# 1              2      2011-05-26      3          4         1  Caroline
# 2              3      2011-06-16      3          3         1  Caroline
# 3              4      2012-08-26      1          2         3   Charles
# 4              5      2013-06-06      2          4         1     Pedro
# 5              6      2013-12-23      2          5         6     Pedro
# 6              7      2013-12-30      3          4         1  Caroline
# 7              8      2014-04-24    NaN          2         3       NaN
# 8              9      2015-04-24      7          4         3       NaN
# 9             10      2016-05-08      3          4         4  Caroline
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3    male 2012-12-21        NaT
# ...

# %% [markdown]
# 13. Which transactions have a UserID not in users?

# %%
#this will first select all userid from transactiona data frame which is present in  users data frame.
# ~ operator will help to select all user id which is not present

transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# 14. Join users to transactions, keeping only rows from transactions and users that
# match via UserID (inner join)

# %%
#merge function of panda takes multiple argumnet like name of data frame to join ,optional argument how takes type of join we 
# we wanr to do (default is inner join), optional argument on takes name of column to join
pd.merge(transactions, users, how="inner", on=['UserID', 'UserID'],sort=False)
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
# 5              5      2013-06-06      2          4         1     Pedro
# 6              6      2013-12-23      2          5         6     Pedro
#
#    Gender Registered  Cancelled
# 0  female 2012-10-23 2016-06-07
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3  female 2012-10-23 2016-06-07
# 4    male 2012-12-21        NaT
# 5    male 2010-08-01 2010-08-08
# 6    male 2010-08-01 2010-08-08

# %% [markdown]
# 15. Join users to transactions, displaying all matching rows AND all non-matching rows
# (full outer join)

# %%
# OUTER JOIN  return all records when there is a match in either left (table1) or right (table2) table records.
# FULL OUTER JOIN can potentially return very large result-sets!. 
# Common column between transactions and users table is UserID
transactions.merge(users, how='outer', left_on=['UserID'], right_on=['UserID'])
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaT     4.0        NaN       NaN   Brielle
# 11            NaN             NaT     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# 16: Determine which sessions occurred on the same day each user registered

# %%
# will see first few rows of session and users data frame to find common column to find each user registered on 
# same day. common column is 'UserID','SessionDate' from session data frame and 'UserID','Registered' column from 
# users data frame. inner join of this 2 data frame using these column will give user registered on same day. 

users.head()
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
users.head()
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT

# %%
# pd.merge(sessions, users, how="inner", on=['SessionDate', 'Registered'],sort=False)
pd.merge(sessions,users,how='inner', left_on=['UserID','SessionDate'], right_on=['UserID','Registered'])
# Out:
#    SessionID SessionDate  UserID     User  Gender Registered  Cancelled
# 0          2  2010-08-01       2    Pedro    male 2010-08-01 2010-08-08
# 1          9  2013-07-17       4  Brielle  female 2013-07-17        NaT

# %% [markdown]
# 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
# users.shape[0] will return 5. Rnp.repeat will repeat value 1 5 times
#pd.merge will join df1 and df2 using column key.After that ['UserID','ProductID'] will select 
# only 2 column from result
df1 = pd.DataFrame({'key':np.repeat(1, users.shape[0]),'UserID':users.UserID})
df2 = pd.DataFrame({'key':np.repeat(1, products.shape[0]),'ProductID':products.ProductID})
pd.merge(df1,df2,on='key')[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# 18. Determine how much quantity of each product was purchased by each user

# %%
# users.shape[0] will return 5. Rnp.repeat will repeat value 1 5 times
#pd.merge will join df1 and df2 using column key.After that ['UserID','ProductID'] will select 
# only 2 column from result
df1 = pd.DataFrame({'key':np.repeat(1, users.shape[0]),'UserID':users.UserID})
df2 = pd.DataFrame({'key':np.repeat(1, products.shape[0]),'ProductID':products.ProductID})
user_products = pd.merge(df1,df2,on='key')[['UserID','ProductID']]
pd.merge(user_products, transactions, how='left', on=['UserID', 'ProductID']).groupby(['UserID', 'ProductID']).apply(
    lambda x: pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %%
19.For each user, get each possible pair of pair transactions (TransactionID1,
TransacationID2)

# %%
# joining same dataframe with key will give each possible pair
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
20. Join each user to his/her first occuring transaction in the transactions table

# %%
# transactions.groupby('UserID').first() will give first first row of each group
# left join of this with users data fram on key userid will give first occuring transactions of each user
pd.merge(users, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')
# Out:
#   UserID      User  Gender Registered  Cancelled  TransactionID  \
# 0      1   Charles    male 2012-12-21        NaT            4.0
# 1      2     Pedro    male 2010-08-01 2010-08-08            5.0
# 2      3  Caroline  female 2012-10-23 2016-06-07            2.0
# 3      4   Brielle  female 2013-07-17        NaT            NaN
# 4      5  Benjamin    male 2010-11-25        NaT            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaT        NaN       NaN
# 4             NaT        NaN       NaN

# %%
21. Test to see if we can drop columns

# %%
#drop will delete column if axxis=1 geven
newusers = users
newusers.drop(['Gender'], axis=1).head(5)
# Out:
#    UserID      User Registered  Cancelled
# 0       1   Charles 2012-12-21        NaT
# 1       2     Pedro 2010-08-01 2010-08-08
# 2       3  Caroline 2012-10-23 2016-06-07
# 3       4   Brielle 2013-07-17        NaT
# 4       5  Benjamin 2010-11-25        NaT

# %%
users
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT

# %% [markdown]
# Other processing steps

# %% [markdown]
# 1. Plot column values as a bar plot

# %%
import matplotlib.pyplot as plt
transactions.plot(kind='bar',x='TransactionID',y='Quantity')

# %% [markdown]
# 2. Saving Data frame in file

# %%
transactions.to_csv('transactions.csv', encoding='utf-8', index=False)

# %% [markdown]
# 3. Put multiple dataframes across separate tabs/sheets

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()

# list of dataframes and sheet names
dfs = [transactions, users, sessions]
sheets = ['transactions','users','sessions']
